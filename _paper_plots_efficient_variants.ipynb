# %%
import os
import numpy             as np
import matplotlib.pyplot as plt
import pandas            as pd 
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)


folder = './plots/paper/'
if not os.path.exists(folder):
    os.makedirs(folder)

# %%
our_color = '#C47B7B'
our_efficient_color = '#DCAEAE'
sdjwt_color = '#87A987'
sdjwt_efficient_color = "#C1E1C1"
pjv_color= '#779ECB'

# %%
our_marker = '+'
our_efficient_marker = 'P'
pjv_marker = 's'
sdjwt_marker = 'x'
sdjwt_efficient_marker = 'X'

# %%
marker_range_10 = range(0,10,1)
marker_range_100 = range(0,100,10)

# %% [markdown]
# # Iterating over permissions

# %% [markdown]
# ### Iterating over permissions - DC Issuance Latency

# %%
# Latencies in issuing DCs when iterating over permissions. Each credential was delegated 10 times. 
# This graph plots the length of the 10th delegated credential when the number of permission varies between 1 and 10.
df = pd.read_csv("./csv_dir/iop_vc_issuance.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Number of permissions")
ax.set_ylabel("Latency (ms)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 1)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Permissions_VC_Issuance.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over permissions - VP Generation Latency

# %%
# Latencies in generating VPs when iterating over permissions. Each credential was delegated 10 times. 
# This graph plots the length of the 10th delegated credential when the number of permission varies between 1 and 10.
# All permissions included in the DC are disclosed.
# Delegators = 10, Permissions = [1...10]
df = pd.read_csv("./csv_dir/iop_vp_issuance.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Number of permissions")
ax.set_ylabel("Latency (ms)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 0.3)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Permissions_VP_Generation.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over permissions - VP Verification Latency

# %%
# Latencies in VP verifications when iterating over permissions. Each credential was delegated 10 times. 
# This graph plots the length of the 10th delegated credential when the number of permission varies between 1 and 10.
# All permissions included in the DC are disclosed.
# Delegators = 10, Permissions = [1...10]
df = pd.read_csv("./csv_dir/iop_vp_verification.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(10))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Number of permissions")
ax.set_ylabel("Latency (ms)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 105)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Permissions_VP_Verification.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over permissions - VP Length

# %%
# JWT Length of VPs when iterating over permissions. Each credential was delegated 10 times. 
# This graph plots the length of the 10th delegated credential when the number of permission varies between 1 and 10.
# All permissions included in the DC are disclosed.
# Delegators = 10, Permissions = [1...10]
df = pd.read_csv("./csv_dir/iop_vp_length.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Number of permissions")
ax.set_ylabel("VP Size (KB)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 45)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Permissions_JWT_Length.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# # Retaining Permissions

# %% [markdown]
# ### Retaining Permissions - DC Issuance Latency

# %%
# Latencies in DC issuance when iterating over permissions. Each VP is formed from a DC that was obtained 
# by delegation. The first credential has 10 permissions and delegates 9 of them. The second credential has 9 
# permissions and delegates 8 of them... 
# Delegators = 10, Permissions = [10...1]
df = pd.read_csv("./csv_dir/rp_vc_issuance.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 1)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Retain_Permissions_VC_Issuance.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Retaining Permissions - VP Generation Latency

# %%
# Latencies in VP generation when iterating over permissions. Each VP is formed from a DC that was obtained 
# by delegation. The first credential has 10 permissions and delegates 9 of them. The second credential has 9 
# permissions and delegates 8 of them... 
# All permissions disclosed.
# Delegators = 10, Permissions = [10...1]
df = pd.read_csv("./csv_dir/rp_vp_issuance.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0.03, 0.3)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Retain_Permissions_VP_Generation.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Retaining Permissions - VP Verification

# %%
# Latencies in VP verification when iterating over permissions. Each VP is formed from a DC that was obtained 
# by delegation. The first credential has 10 permissions and delegates 9 of them. The second credential has 9 
# permissions and delegates 8 of them... 
# All permissions disclosed.
# Delegators = 10, Permissions = [10...1]
df = pd.read_csv("./csv_dir/rp_vp_verification.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 40)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Retain_Permissions_VP_Verification.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Retaining Permissions - VP Length

# %%
# JWT Length of VPs. Each VP is formed from a DC that was obtained by delegation. The first credential has 10
# permissions and delegates 9 of them. The second credential has 9 permissions and delegates 8 of them...
# All permissions disclosed.
# Delegators = 10, Permissions = [10...1]
df = pd.read_csv("./csv_dir/rp_vp_length.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("VP Size (KB)")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 40)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Retain_Permissions_JWT_Length.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# # Iterating over delegators (10/10 permissions disclosed)

# %% [markdown]
# ### Iterating over delegators (10/10) - DC Issuance Latency

# %%
# Latencies introduced in issuing DCs. Each VP is formed from a DC that was obtained by delegation. 
# Each DC that is obtained by delegation has 10 permissions and is delegated from delegator to delegatee 10 
# times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
df = pd.read_csv("./csv_dir/iod_vc_issuance_10.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms) [10/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 1)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_10_Disclosures_VC_Issuance.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over delegators (10/10) - VP Generation

# %%
# Latencies introduced in generating VPs. Each VP is formed from a DC that was obtained by delegation. 
# Each DC that is obtained by delegation has 10 permissions and is delegated from delegator to delegatee 10 
# times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
# The graph plots the latencies in generating VPs from each of these credentials in which the presenter discloses
# 10/10 permissions.
# Delegators = [1...10], Permissions = 10, Disclosures = 10
df = pd.read_csv("./csv_dir/iod_vp_issuance_10.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms) [10/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 0.3)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_10_Disclosures_VP_Generation.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over delegators (10/10) - VP Verification

# %%
# Latencies introduced in verifying VPs. Each VP is formed from a DC that was obtained by delegation. 
# Each DC that is obtained by delegation has 10 permissions and is delegated from delegator to delegatee 10 
# times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
# The graph plots the latencies in verifying VPs from each of these credentials in which the presenter discloses
# 10/10 permissions.
# Delegators = [1...10], Permissions = 10, Disclosures = 10
df = pd.read_csv("./csv_dir/iod_vp_verification_10.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(10))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms) [10/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 105)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_10_Disclosures_VP_Generation.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over delegators (10/10) - VP Length

# %%
# JWT Length of VPs. Each VP is formed from a DC that was obtained by delegation. Each DC that is obtained by 
# delegation has 10 permissions and is delegated from delegator to delegatee 10 times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
# The graph plots the lengths of VPs generated from each of these credentials in which the presenter discloses 
# 10/10 permissions.
# Delegators = [1...10], Permissions = 10, Disclosures = 10
df = pd.read_csv("./csv_dir/iod_vp_length_10.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("VP Size (KB) [10/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 45)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_10_Disclosures_JWT_Length.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# # Iterating over delegators (1/10 permissions disclosed)

# %% [markdown]
# ### Iterating over delegators (1/10) - DC Issuance

# %%
# Latencies introduced in issuing DCs. Each VP is formed from a DC that was obtained by delegation. 
# Each DC that is obtained by delegation has 10 permissions and is delegated from delegator to delegatee 10 
# times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
df = pd.read_csv("./csv_dir/iod_vc_issuance_1.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms) [1/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 1)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_1_Disclosure_VC_Issuance.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over delegators (1/10) - VP Generation

# %%
# Latencies introduced in generating VPs. Each VP is formed from a DC that was obtained by delegation. 
# Each DC that is obtained by delegation has 10 permissions and is delegated from delegator to delegatee 10 
# times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
# The graph plots the latencies in generating VPs from each of these credentials in which the presenter discloses
# 1/10 permissions.
# Delegators = [1...10], Permissions = 10, Disclosures = 1
df = pd.read_csv("./csv_dir/iod_vp_issuance_1.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms) [1/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 0.3)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_1_Disclosure_VP_Generation.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over delegators (1/10) - VP Verification

# %%
# Latencies introduced in verifying VPs. Each VP is formed from a DC that was obtained by delegation. 
# Each DC that is obtained by delegation has 10 permissions and is delegated from delegator to delegatee 10 
# times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
# The graph plots the latencies in verifying VPs from each of these credentials in which the presenter discloses
# 1/10 permissions.
# Delegators = [1...10], Permissions = 10, Disclosures = 10
df = pd.read_csv("./csv_dir/iod_vp_verification_1.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(10))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("Latency (ms) [1/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 20)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_1_Disclosure_VP_Verification.pdf", dpi=600, format='pdf')
plt.show()

# %% [markdown]
# ### Iterating over delegators (1/10) - VP Length

# %%
# JWT Length of VPs. Each VP is formed from a DC that was obtained by delegation. Each DC that is obtained by 
# delegation has 10 permissions and is delegated from delegator to delegatee 10 times as follows:
#      Delegator D0 -> Delegatee D1
#      Delegator D1 -> Delegatee D2
#      ...
#      Delegator D9 -> Delegatee D10
# The graph plots the VPs generated from each of these credentials in which the presenter discloses 1/10 permissions
# Delegators = [1...10], Permissions = 10, Disclosures = 1
df = pd.read_csv("./csv_dir/iod_vp_length_1.csv")
fig, ax = plt.subplots()
x = range(1,11,1)

ax.plot(x, df['Ours'] / 1000, label='Ours', color=our_color, marker=our_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['OursEfficient'] / 1000, label='Ours Efficient', color=our_efficient_color, marker=our_efficient_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['PJVs'] / 1000, label='Vrielynck et al.', color=pjv_color, marker=pjv_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWT'] / 1000, label='SD-JWT', color=sdjwt_color, marker=sdjwt_marker, markevery=marker_range_10, linewidth=2)
ax.plot(x, df['SdJWTEfficient'] / 1000, label='SD-JWT Efficient', color=sdjwt_efficient_color, marker=sdjwt_efficient_marker, markevery=marker_range_10, linewidth=2)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.set_xlabel("Delegation chain length")
ax.set_ylabel("VP Size (KB) [1/10 Permissions Disclosed]")

ax.legend(loc="upper left", fancybox=True, framealpha=0.4, prop={'size': 9})

plt.xlim(0.9, 10.1)
plt.ylim(0, 45)

plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.savefig(f"{folder}/Iterating_Over_Delegators_1_Disclosure_JWT_Length.pdf", dpi=600, format='pdf')
plt.show()
